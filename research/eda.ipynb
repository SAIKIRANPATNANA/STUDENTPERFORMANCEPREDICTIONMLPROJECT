# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# %pwd
# Out:
# '/home/user/Documents/ML DL PROJECTS/StudentPerformancePredictionMLProject/research'

# %%
cd StudentPerformancePredictionMLProject
# Out:
# [Errno 2] No such file or directory: 'StudentPerformancePredictionMLProject'
# /home/user/Documents/ML DL PROJECTS/StudentPerformancePredictionMLProject/research

# %%
# %pwd
# Out:
# '/home/user/Documents/ML DL PROJECTS/StudentPerformancePredictionMLProject/research'

# %%
import os
os.chdir('../')

# %%
df = pd.read_csv("datasets/StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
for col in df.columns:
    print(col,df[col].unique())
# Out:
# gender ['female' 'male']
# race/ethnicity ['group B' 'group C' 'group A' 'group D' 'group E']
# parental level of education ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# lunch ['standard' 'free/reduced']
# test preparation course ['none' 'completed']
# math score [ 72  69  90  47  76  71  88  40  64  38  58  65  78  50  18  46  54  66
#   44  74  73  67  70  62  63  56  97  81  75  57  55  53  59  82  77  33
#   52   0  79  39  45  60  61  41  49  30  80  42  27  43  68  85  98  87
#   51  99  84  91  83  89  22 100  96  94  48  35  34  86  92  37  28  24
#   26  95  36  29  32  93  19  23   8]
# reading score [ 72  90  95  57  78  83  43  64  60  54  52  81  53  75  89  32  42  58
#   69  73  71  74  70  65  87  56  61  84  55  44  41  85  59  17  39  80
#   37  63  51  49  26  68  45  47  86  34  79  66  67  91 100  76  77  82
#   92  93  62  88  50  28  48  46  23  38  94  97  99  31  96  24  29  40]
# writing score [ 74  88  93  44  75  78  92  39  67  50  52  43  73  70  58  86  28  46
#   61  63  53  80  72  55  65  38  82  79  83  59  57  54  68  66  62  76
#   48  42  87  49  10  34  71  37  56  41  22  81  45  36  89  47  90 100
#   64  98  51  40  84  69  33  60  85  91  77  27  94  95  19  35  32  96
#   97  99  15  30  23]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (3.6.6)
# Requirement already satisfied: ydata-profiling in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from pandas-profiling) (4.6.0)
# Requirement already satisfied: scipy<1.12,>=1.4.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (1.10.1)
# Requirement already satisfied: pandas!=1.4.0,<2.1,>1.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (2.0.3)
# Requirement already satisfied: matplotlib<=3.7.3,>=3.2 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (3.7.3)
# Requirement already satisfied: pydantic<2,>=1.8.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (1.10.13)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (3.1.2)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (0.7.5)
# Requirement already satisfied: numpy<1.26,>=1.16.0 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (1.24.4)
# Requirement already satisfied: htmlmin==0.1.12 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (0.12.3)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (4.66.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (1.10)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (0.14.0)
# Requirement already satisfied: typeguard<5,>=4.1.2 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (4.1.5)
# Requirement already satisfied: imagehash==4.3.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (1.9.2)
# Requirement already satisfied: dacite>=1.8 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (1.8.1)
# Requirement already satisfied: numba<0.59.0,>=0.56.0 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (0.58.0)
# Requirement already satisfied: PyWavelets in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.4.1)
# Requirement already satisfied: pillow in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (10.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from matplotlib<=3.7.3,>=3.2->ydata-profiling->pandas-profiling) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from matplotlib<=3.7.3,>=3.2->ydata-profiling->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from matplotlib<=3.7.3,>=3.2->ydata-profiling->pandas-profiling) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from matplotlib<=3.7.3,>=3.2->ydata-profiling->pandas-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from matplotlib<=3.7.3,>=3.2->ydata-profiling->pandas-profiling) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from matplotlib<=3.7.3,>=3.2->ydata-profiling->pandas-profiling) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from matplotlib<=3.7.3,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from matplotlib<=3.7.3,>=3.2->ydata-profiling->pandas-profiling) (6.1.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from numba<0.59.0,>=0.56.0->ydata-profiling->pandas-profiling) (0.41.0)
# Requirement already satisfied: importlib-metadata in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from numba<0.59.0,>=0.56.0->ydata-profiling->pandas-profiling) (6.8.0)
# Requirement already satisfied: pytz>=2020.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling->pandas-profiling) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling->pandas-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.3.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from pydantic<2,>=1.8.1->ydata-profiling->pandas-profiling) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.2 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.3)
# Requirement already satisfied: zipp>=0.5 in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from importlib-metadata->numba<0.59.0,>=0.56.0->ydata-profiling->pandas-profiling) (3.17.0)
# Requirement already satisfied: six in /home/user/anaconda3/envs/student/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
# pip install pandas-profiling --upgrade

# %%
# profile = ProfileReport(df, title="Pandas Profiling Report")
# profile.to_file("report.html")

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
num_features = [feature for feature in df.columns if df[feature].dtype!='O']
cat_features = [feature for feature in df.columns if df[feature].dtype=='O']

# %%
num_features
# Out:
# ['math score', 'reading score', 'writing score']

# %%
cat_features
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course']

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['total_score'] = df['math score']+df['reading score']+df['writing score']

# %%
df['average'] = df['total_score']/3

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# 4          229  76.333333

# %%
len(df[df['reading score']<=20])
# Out:
# 1

# %%
len(df[df['writing score']<=20])
# Out:
# 3

# %%
len(df[df['math score']<=20])
# Out:
# 4

# %%
fig, axs = plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='average', bins=30, kde=True, color='g')
plt.subplot(122)
sns.histplot(data=df,x='average', kde=True, hue='gender')
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='total_score', bins=30, kde=True, color='g')
plt.subplot(122)
sns.histplot(data=df,x='total_score', kde=True, hue='gender')
plt.show()

# %%
# female pupil are perforing well than the male pupil

# %%
plt.subplots(1,3,figsize=(10,10))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='lunch')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='lunch')
plt.show()

# %%
# performance of the student't taking standard food is better than those of taking free/reduced food

# %%
plt.subplots(1,3,figsize=(15,6))
plt.subplot(141)
ax =sns.histplot(data=df,x='average',kde=True,hue='parental level of education')
plt.subplot(142)

X = ['Total Average','Math Average']
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='parental level of education')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='parental level of education')
plt.show()

# %%
plt.subplots(1,3,figsize=(15,6))
plt.subplot(141)
ax =sns.histplot(data=df,x='average',kde=True,hue='race/ethnicity')
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='race/ethnicity')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='race/ethnicity')
plt.show()

# %%
plt.figure(figsize=(18,8))
plt.subplot(1, 4, 1)
plt.title('MATH SCORES')
sns.violinplot(y='math score',data=df,color='red',linewidth=3)
plt.subplot(1, 4, 2)
plt.title('READING SCORES')
sns.violinplot(y='reading score',data=df,color='green',linewidth=3)
plt.subplot(1, 4, 3)
plt.title('WRITING SCORES')
sns.violinplot(y='writing score',data=df,color='blue',linewidth=3)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (30, 30)

plt.subplot(1, 5, 1)
size = df['gender'].value_counts()
labels = 'Female', 'Male'
color = ['red','green']
plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Gender', fontsize = 20)
plt.axis('off')
plt.subplot(1, 5, 2)
size = df['race/ethnicity'].value_counts()
labels = 'Group C', 'Group D','Group B','Group E','Group A'
color = ['red', 'green', 'blue', 'cyan','orange']
plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Race/Ethnicity', fontsize = 20)
plt.axis('off')
plt.subplot(1, 5, 3)
size = df['lunch'].value_counts()
labels = 'Standard', 'Free'
color = ['red','green']
plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Lunch', fontsize = 20)
plt.axis('off')
plt.subplot(1, 5, 4)
size = df['test preparation course'].value_counts()
labels = 'None', 'Completed'
color = ['red','green']
plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Test Course', fontsize = 20)
plt.axis('off')
plt.subplot(1, 5, 5)
size = df['parental level of education'].value_counts()
labels = 'Some College', "Associate's Degree",'High School','Some High School',"Bachelor's Degree","Master's Degree"
color = ['red', 'green', 'blue', 'cyan','orange','grey']
plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Parental Education', fontsize = 20)
plt.axis('off')
plt.tight_layout()
plt.grid()
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
sns.countplot(x=df['gender'],data=df,palette ='bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
plt.pie(x=df['gender'].value_counts(),labels=['Male','Female'],explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'])
plt.show()

# %%
Group_data2=df.groupby('race/ethnicity')
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.barplot(x=Group_data2['math score'].mean().index,y=Group_data2['math score'].mean().values,palette = 'mako',ax=ax[0])
ax[0].set_title('Math score',color='#005ce6',size=20)

for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=15)

sns.barplot(x=Group_data2['reading score'].mean().index,y=Group_data2['reading score'].mean().values,palette = 'flare',ax=ax[1])
ax[1].set_title('Reading score',color='#005ce6',size=20)

for container in ax[1].containers:
    ax[1].bar_label(container,color='black',size=15)

sns.barplot(x=Group_data2['writing score'].mean().index,y=Group_data2['writing score'].mean().values,palette = 'coolwarm',ax=ax[2])
ax[2].set_title('Writing score',color='#005ce6',size=20)

for container in ax[2].containers:
    ax[2].bar_label(container,color='black',size=15)

# %%
import seaborn as sns

# %%
# plt.rcParams['figure.figsize'] = (15, 9)
# plt.style.use('fivethirtyeight')
# sns.countplot(df['parental level of education'], palette = 'Blues')
# plt.title('Comparison of Parental Education', fontweight = 30, fontsize = 20)
# plt.xlabel('Degree')
# plt.ylabel('count')
# plt.show()

# %%
# df.groupby('parental level of education').agg('mean').plot(kind='barh',figsize=(10,10))
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 9)
plt.style.use('seaborn-talk')
# sns.countplot(df['lunch'], palette = 'PuBu')
plt.title('Comparison of different types of lunch', fontweight = 30, fontsize = 20)
plt.xlabel('types of lunch')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,2,1)
sns.barplot (x=df['lunch'], y=df['math score'], hue=df['test preparation course'])
plt.subplot(2,2,2)
sns.barplot (x=df['lunch'], y=df['reading score'], hue=df['test preparation course'])
plt.subplot(2,2,3)
sns.barplot (x=df['lunch'], y=df['writing score'], hue=df['test preparation course'])
# Out:
# <Axes: xlabel='lunch', ylabel='writing score'>

# %%
plt.subplots(1,4,figsize=(16,5))
plt.subplot(141)
sns.boxplot(df['math score'],color='skyblue')
plt.subplot(142)
sns.boxplot(df['reading score'],color='hotpink')
plt.subplot(143)
sns.boxplot(df['writing score'],color='yellow')
plt.subplot(144)
sns.boxplot(df['average'],color='lightgreen')
plt.show()

# %%
sns.pairplot(df,hue = 'gender')
plt.show()
